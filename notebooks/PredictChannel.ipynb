# %%
import json
import glob
import os
import datetime
import re
from slack_data_loader import SlackLoader, normalize_links
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
#%load_ext autoreload
#%autoreload 2

# %%
# data_folder = '/Users/alex/Documents/ODS/oct_4_2016_dump'
data_folder = '../input/export_Feb_8_2018'
ods = SlackLoader(data_folder)

# %% [markdown]
# ## Message types

# %%
df_msg = pd.DataFrame.from_records(ods.messages)

# %%
df_msg[df_msg["subtype"].isnull()].to_csv("messages.csv")

# %%
df_msg[df_msg["attachments"]]

"attachments", "edited", "reactions"
mentions_with_id = pd.io.json.json_normalize(resp.json(), record_path='mentions', meta='id',
                                     record_prefix='mentions.')
mentions_with_id.head()

# %%
df_msg.fillna(0).groupby(['type', 'subtype'])['dt'].count()
# Out:
# type     subtype
# message  0                   614216
#          bot_add                 12
#          bot_message           8571
#          bot_remove               6
#          channel_join        109295
#          channel_leave         5511
#          channel_name            40
#          channel_purpose        115
#          channel_topic          322
#          file_comment          2288
#          file_mention           226
#          file_share            7105
#          me_message              14
#          pinned_item            915
#          reminder_add            29
#          reply_broadcast        646
#          sh_room_created          2
#          thread_broadcast       589
#          tombstone              455
# Name: dt, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.snowball import EnglishStemmer, RussianStemmer

ru_stemmer = RussianStemmer()
en_stemmer = EnglishStemmer()
analyzer = CountVectorizer().build_analyzer()

def is_russian_word(w):
    #if not isinstance(w, unicode):
    #    w = w.decode('utf8')
    for c in w:
        if ord(c) >= ord(u'а') and ord(c) <= ord(u'я'):
            return True
    return False

def stemmed_words(doc):
    for w in analyzer(doc):
        yield ru_stemmer.stem(w) if is_russian_word(w) else en_stemmer.stem(w)

# %%
from tqdm import tqdm

# %%
# %%time
vectorizer = TfidfVectorizer(min_df=5, analyzer=stemmed_words).fit(all_texts)
# Out:
# CPU times: user 7min 10s, sys: 6.56 s, total: 7min 16s
# Wall time: 7min 20s

# %%
from __future__ import print_function

# %%
from operator import itemgetter

# %%
vectorizer?

# %%
for _item in sample(vectorizer.stop_words_,100):
    print(_item,end='\t')
# Out:
# serega_ang	find_weight	потетст	rpp7zhgb1iq	ушлепк	38811	images4	контрацепц	gael	u6sc27y64	бпе	5bhb_rhbqye	cyborg	многиз	xproger	ануса	gpasswd	неладя	1kc1qqgqtzrbqugjbst83mpycfrgmhygud	buzova	00004	комибинац	zhivy	рассказыаа	reliant	моежт	00019660	1486039460	металоформ	croni	fanfic	random2	schitaet	печкозион	msg00308	toadworld	aidraw	show_desc	омп	texts_to_sequ	charlesshang	mithfin	p1459072442000682	55860	gpucomput	sja7xfb0b	opasen	флажочек	153646673_127	716078	обязаловок	268661	087	euclid	diagnocat	грохот	pondruska	видюшек	переоткрыт	24385	схвач	055f8e9c	копираван	попреподава	inputobject	da1	9435	синод	279798	затеб	_плотить_	матиш	pluggabl	336094	полупижам	container_fold	разбогатевш	p1469004763000081	rperform	wjgyj	липованин	987590	лесб	802578	15pca	895016751423008771	jwm40	подрастеш	чолович	rabotodatelei	подсоединен	dobavil	вован	бэкслэш	inquisitr	lilu	ркарсон	8тта	02815	_декорирование_

# %%
for _word, _count in sorted(vectorizer.vocabulary_.items(),key=itemgetter(1),reverse=True)[:20]:
    print(_word,end=' ')
    print(_count)
# Out:
# ящичк 44437
# ящита 44436
# ящик 44435
# ящета 44434
# яш 44433
# ячейк 44432
# ячеек 44431
# яхт 44430
# ях 44429
# ят 44428
# ясност 44427
# ясненьк 44426
# ясн 44425
# ясер 44424
# ясен 44423
# яс 44422
# ярч 44421
# ярош 44420
# яростн 44419
# ярост 44418

# %%
msg
# Out:
#                                               attachments bot_id bot_link  \
# 4                                                     NaN    NaN      NaN
# 7                                                     NaN    NaN      NaN
# 14                                                    NaN    NaN      NaN
# 15                                                    NaN    NaN      NaN
# 16                                                    NaN    NaN      NaN
# 17                                                    NaN    NaN      NaN
# 22                                                    NaN    NaN      NaN
# 25                                                    NaN    NaN      NaN
# 26                                                    NaN    NaN      NaN
# 33                                                    NaN    NaN      NaN
# 34                                                    NaN    NaN      NaN
# 35                                                    NaN    NaN      NaN
# 36                                                    NaN    NaN      NaN
# 40                                                    NaN    NaN      NaN
# 43                                                    NaN    NaN      NaN
# 44                                                    NaN    NaN      NaN
# 45                                                    NaN    NaN      NaN
# 52      [{'fallback': 'Stitch Fix is a full-stack star...    NaN      NaN
# 57                                                    NaN    NaN      NaN
# 58      [{'id': 1, 'title': 'Python Graphing Library |...    NaN      NaN
# 59                                                    NaN    NaN      NaN
# 60                                                    NaN    NaN      NaN
# 61      [{'id': 1, 'title': 'Show Me Shiny', 'fallback...    NaN      NaN
# 62      [{'id': 1, 'fallback': '625x351px image', 'fro...    NaN      NaN
# 65                                                    NaN    NaN      NaN
# 66                                                    NaN    NaN      NaN
# 68                                                    NaN    NaN      NaN
# 69                                                    NaN    NaN      NaN
# 70                                                    NaN    NaN      NaN
# 71                                                    NaN    NaN      NaN
# ...                                                   ...    ...      ...
# 750327                                                NaN    NaN      NaN
# 750328                                                NaN    NaN      NaN
# 750329                                                NaN    NaN      NaN
# 750330                                                NaN    NaN      NaN
# 750331                                                NaN    NaN      NaN
# 750332  [{'id': 1, 'title': 'Launch a GPU-backed Googl...    NaN      NaN
# 750333                                                NaN    NaN      NaN
# 750334                                                NaN    NaN      NaN
# 750335                                                NaN    NaN      NaN
# 750336                                                NaN    NaN      NaN
# 750337                                                NaN    NaN      NaN
# 750338                                                NaN    NaN      NaN
# 750339                                                NaN    NaN      NaN
# 750340                                                NaN    NaN      NaN
# 750341                                                NaN    NaN      NaN
# 750342                                                NaN    NaN      NaN
# 750343                                                NaN    NaN      NaN
# 750344                                                NaN    NaN      NaN
# 750345                                                NaN    NaN      NaN
# 750346                                                NaN    NaN      NaN
# 750347  [{'from_url': 'https://uber.github.io/deck.gl/...    NaN      NaN
# 750348                                                NaN    NaN      NaN
# 750349                                                NaN    NaN      NaN
# 750350                                                NaN    NaN      NaN
# 750351                                                NaN    NaN      NaN
# 750352                                                NaN    NaN      NaN
# 750353                                                NaN    NaN      NaN
# 750354                                                NaN    NaN      NaN
# 750355                                                NaN    NaN      NaN
# 750356                                                NaN    NaN      NaN
#
#           channel channel_id                         client_msg_id comment  \
# 4       C040HKJEZ        NaN                                   NaN     NaN
# 7       C040HKJEZ        NaN                                   NaN     NaN
# 14      C040HKJEZ        NaN                                   NaN     NaN
# 15      C040HKJEZ        NaN                                   NaN     NaN
# 16      C040HKJEZ        NaN                                   NaN     NaN
# 17      C040HKJEZ        NaN                                   NaN     NaN
# 22      C040HKJEZ        NaN                                   NaN     NaN
# 25      C040HKJEZ        NaN                                   NaN     NaN
# 26      C040HKJEZ        NaN                                   NaN     NaN
# 33      C040HKJEZ        NaN                                   NaN     NaN
# 34      C040HKJEZ        NaN                                   NaN     NaN
# 35      C040HKJEZ        NaN                                   NaN     NaN
# 36      C040HKJEZ        NaN                                   NaN     NaN
# 40      C040HKJEZ        NaN                                   NaN     NaN
# 43      C040HKJEZ        NaN                                   NaN     NaN
# 44      C040HKJEZ        NaN                                   NaN     NaN
# 45      C040HKJEZ        NaN                                   NaN     NaN
# 52      C040HKJEZ        NaN                                   NaN     NaN
# 57      C040HKJEZ        NaN                                   NaN     NaN
# 58      C040HKJEZ        NaN                                   NaN     NaN
# 59      C040HKJEZ        NaN                                   NaN     NaN
# 60      C040HKJEZ        NaN                                   NaN     NaN
# 61      C040HKJEZ        NaN                                   NaN     NaN
# 62      C040HKJEZ        NaN                                   NaN     NaN
# 65      C040HKJF1        NaN                                   NaN     NaN
# 66      C040HKJF1        NaN                                   NaN     NaN
# 68      C040HKJF1        NaN                                   NaN     NaN
# 69      C040HKJF1        NaN                                   NaN     NaN
# 70      C040HKJF1        NaN                                   NaN     NaN
# 71      C040HKJF1        NaN                                   NaN     NaN
# ...           ...        ...                                   ...     ...
# 750327  C0CLJ8C82        NaN                                   NaN     NaN
# 750328  C6UMR8CFN        NaN                                   NaN     NaN
# 750329  C39147V60        NaN                                   NaN     NaN
# 750330  C04422A5C        NaN                                   NaN     NaN
# 750331  C043ZEF6K        NaN                                   NaN     NaN
# 750332  C043ZEF6K        NaN                                   NaN     NaN
# 750333  C04422A5C        NaN                                   NaN     NaN
# 750334  C0SGCGB52        NaN  0518bc5c-b221-49b0-aeed-a5b67b865bd3     NaN
# 750335  C39147V60        NaN                                   NaN     NaN
# 750336  C040HKJF1        NaN  DC45D2B5-D982-493D-BE71-3C2E7641EB45     NaN
# 750337  C91N8TL83        NaN                                   NaN     NaN
# 750338  C0SGCGB52        NaN                                   NaN     NaN
# 750339  C04N3UMSL        NaN                                   NaN     NaN
# 750340  C047H3DP4        NaN                                   NaN     NaN
# 750341  C04N3UMSL        NaN                                   NaN     NaN
# 750342  C39147V60        NaN                                   NaN     NaN
# 750343  C040HKJF1        NaN                                   NaN     NaN
# 750344  C040HKJF1        NaN                                   NaN     NaN
# 750345  C6UMR8CFN        NaN                                   NaN     NaN
# 750346  C047H3DP4        NaN                                   NaN     NaN
# 750347  C04655480        NaN                                   NaN     NaN
# 750348  C04655480        NaN                                   NaN     NaN
# 750349  C047H3DP4        NaN                                   NaN     NaN
# 750350  C04655480        NaN                                   NaN     NaN
# 750351  C047H3DP4        NaN                                   NaN     NaN
# 750352  C04655480        NaN                                   NaN     NaN
# 750353  C040HKJF1        NaN                                   NaN     NaN
# 750354  C39147V60        NaN                                   NaN     NaN
# 750355  C39147V60        NaN                                   NaN     NaN
# 750356  C04655480        NaN                                   NaN     NaN
#
#        display_as_bot                         dt  \
# 4                 NaN 2015-03-12 12:31:12.000003
# 7                 NaN 2015-03-15 21:26:37.000002
# 14                NaN 2015-03-16 05:39:06.000006
# 15                NaN 2015-03-16 05:42:30.000007
# 16                NaN 2015-03-16 05:44:02.000008
# 17                NaN 2015-03-16 05:45:16.000009
# 22                NaN 2015-03-16 14:38:38.000012
# 25                NaN 2015-03-16 15:24:41.000014
# 26                NaN 2015-03-16 15:26:08.000015
# 33                NaN 2015-03-17 07:35:51.000019
# 34                NaN 2015-03-17 07:38:43.000020
# 35                NaN 2015-03-17 07:39:10.000023
# 36                NaN 2015-03-17 07:39:30.000024
# 40                NaN 2015-03-18 15:45:54.000027
# 43                NaN 2015-03-18 16:26:36.000029
# 44                NaN 2015-03-18 16:27:10.000030
# 45                NaN 2015-03-18 16:31:34.000031
# 52                NaN 2015-03-19 20:30:26.000003
# 57                NaN 2015-03-20 10:35:58.000002
# 58                NaN 2015-03-20 10:36:30.000003
# 59                NaN 2015-03-20 10:57:18.000005
# 60                NaN 2015-03-20 10:59:05.000006
# 61                NaN 2015-03-20 11:02:24.000007
# 62                NaN 2015-03-20 11:08:22.000009
# 65                NaN 2015-03-21 10:33:36.000003
# 66                NaN 2015-03-21 10:56:15.000004
# 68                NaN 2015-03-21 11:00:50.000006
# 69                NaN 2015-03-21 11:04:06.000007
# 70                NaN 2015-03-21 11:04:30.000009
# 71                NaN 2015-03-21 11:06:01.000010
# ...               ...                        ...
# 750327            NaN 2018-02-08 18:06:05.000764
# 750328            NaN 2018-02-08 18:06:07.000105
# 750329            NaN 2018-02-08 18:06:17.000748
# 750330            NaN 2018-02-08 18:06:38.000434
# 750331            NaN 2018-02-08 18:06:51.000690
# 750332            NaN 2018-02-08 18:06:55.000673
# 750333            NaN 2018-02-08 18:07:55.000600
# 750334            NaN 2018-02-08 18:09:22.000072
# 750335            NaN 2018-02-08 18:09:42.000386
# 750336            NaN 2018-02-08 18:11:27.000133
# 750337            NaN 2018-02-08 18:11:50.000550
# 750338            NaN 2018-02-08 18:13:59.000795
# 750339            NaN 2018-02-08 18:18:00.000756
# 750340            NaN 2018-02-08 18:18:40.000073
# 750341            NaN 2018-02-08 18:18:45.000774
# 750342            NaN 2018-02-08 18:21:24.000616
# 750343            NaN 2018-02-08 18:21:37.000274
# 750344            NaN 2018-02-08 18:22:13.000242
# 750345            NaN 2018-02-08 18:23:06.000511
# 750346            NaN 2018-02-08 18:31:16.000748
# 750347            NaN 2018-02-08 18:32:07.000364
# 750348            NaN 2018-02-08 18:34:07.000328
# 750349            NaN 2018-02-08 18:34:08.000154
# 750350            NaN 2018-02-08 18:34:28.000596
# 750351            NaN 2018-02-08 18:34:44.000417
# 750352            NaN 2018-02-08 18:34:52.000515
# 750353            NaN 2018-02-08 18:37:56.000847
# 750354            NaN 2018-02-08 18:38:02.000050
# 750355            NaN 2018-02-08 18:38:18.000518
# 750356            NaN 2018-02-08 18:38:59.000436
#
#                                                   edited   ...    topic  \
# 4                                                    NaN   ...      NaN
# 7                                                    NaN   ...      NaN
# 14                                                   NaN   ...      NaN
# 15                                                   NaN   ...      NaN
# 16                                                   NaN   ...      NaN
# 17                                                   NaN   ...      NaN
# 22                                                   NaN   ...      NaN
# 25                                                   NaN   ...      NaN
# 26                                                   NaN   ...      NaN
# 33                                                   NaN   ...      NaN
# 34      {'ts': '1426567140.000000', 'user': 'U040M0W0S'}   ...      NaN
# 35                                                   NaN   ...      NaN
# 36                                                   NaN   ...      NaN
# 40                                                   NaN   ...      NaN
# 43                                                   NaN   ...      NaN
# 44                                                   NaN   ...      NaN
# 45                                                   NaN   ...      NaN
# 52                                                   NaN   ...      NaN
# 57                                                   NaN   ...      NaN
# 58                                                   NaN   ...      NaN
# 59                                                   NaN   ...      NaN
# 60                                                   NaN   ...      NaN
# 61                                                   NaN   ...      NaN
# 62                                                   NaN   ...      NaN
# 65                                                   NaN   ...      NaN
# 66                                                   NaN   ...      NaN
# 68                                                   NaN   ...      NaN
# 69      {'ts': '1426925055.000000', 'user': 'U041T0UHM'}   ...      NaN
# 70                                                   NaN   ...      NaN
# 71                                                   NaN   ...      NaN
# ...                                                  ...   ...      ...
# 750327                                               NaN   ...      NaN
# 750328                                               NaN   ...      NaN
# 750329                                               NaN   ...      NaN
# 750330                                               NaN   ...      NaN
# 750331                                               NaN   ...      NaN
# 750332                                               NaN   ...      NaN
# 750333                                               NaN   ...      NaN
# 750334                                               NaN   ...      NaN
# 750335                                               NaN   ...      NaN
# 750336                                               NaN   ...      NaN
# 750337                                               NaN   ...      NaN
# 750338                                               NaN   ...      NaN
# 750339                                               NaN   ...      NaN
# 750340                                               NaN   ...      NaN
# 750341                                               NaN   ...      NaN
# 750342                                               NaN   ...      NaN
# 750343                                               NaN   ...      NaN
# 750344                                               NaN   ...      NaN
# 750345                                               NaN   ...      NaN
# 750346  {'ts': '1518103895.000000', 'user': 'U7ZRN37U2'}   ...      NaN
# 750347                                               NaN   ...      NaN
# 750348                                               NaN   ...      NaN
# 750349                                               NaN   ...      NaN
# 750350                                               NaN   ...      NaN
# 750351                                               NaN   ...      NaN
# 750352                                               NaN   ...      NaN
# 750353                                               NaN   ...      NaN
# 750354                                               NaN   ...      NaN
# 750355  {'ts': '1518104319.000000', 'user': 'U1HHX1QS3'}   ...      NaN
# 750356                                               NaN   ...      NaN
#
#                   ts     type unfurl_links unfurl_media unread_count upload  \
# 4       1.426153e+09  message          NaN          NaN          NaN    NaN
# 7       1.426444e+09  message          NaN          NaN          NaN    NaN
# 14      1.426474e+09  message          NaN          NaN          NaN    NaN
# 15      1.426474e+09  message          NaN          NaN          NaN    NaN
# 16      1.426474e+09  message          NaN          NaN          NaN    NaN
# 17      1.426474e+09  message          NaN          NaN          NaN    NaN
# 22      1.426506e+09  message          NaN          NaN          NaN    NaN
# 25      1.426509e+09  message          NaN          NaN          NaN    NaN
# 26      1.426509e+09  message          NaN          NaN          NaN    NaN
# 33      1.426567e+09  message          NaN          NaN          NaN    NaN
# 34      1.426567e+09  message          NaN          NaN          NaN    NaN
# 35      1.426567e+09  message          NaN          NaN          NaN    NaN
# 36      1.426567e+09  message          NaN          NaN          NaN    NaN
# 40      1.426683e+09  message          NaN          NaN          NaN    NaN
# 43      1.426685e+09  message          NaN          NaN          NaN    NaN
# 44      1.426685e+09  message          NaN          NaN          NaN    NaN
# 45      1.426685e+09  message          NaN          NaN          NaN    NaN
# 52      1.426786e+09  message          NaN          NaN          NaN    NaN
# 57      1.426837e+09  message          NaN          NaN          NaN    NaN
# 58      1.426837e+09  message          NaN          NaN          NaN    NaN
# 59      1.426838e+09  message          NaN          NaN          NaN    NaN
# 60      1.426838e+09  message          NaN          NaN          NaN    NaN
# 61      1.426839e+09  message          NaN          NaN          NaN    NaN
# 62      1.426839e+09  message          NaN          NaN          NaN    NaN
# 65      1.426923e+09  message          NaN          NaN          NaN    NaN
# 66      1.426925e+09  message          NaN          NaN          NaN    NaN
# 68      1.426925e+09  message          NaN          NaN          NaN    NaN
# 69      1.426925e+09  message          NaN          NaN          NaN    NaN
# 70      1.426925e+09  message          NaN          NaN          NaN    NaN
# 71      1.426925e+09  message          NaN          NaN          NaN    NaN
# ...              ...      ...          ...          ...          ...    ...
# 750327  1.518102e+09  message          NaN          NaN          NaN    NaN
# 750328  1.518102e+09  message          NaN          NaN          NaN    NaN
# 750329  1.518102e+09  message          NaN          NaN          NaN    NaN
# 750330  1.518102e+09  message          NaN          NaN          NaN    NaN
# 750331  1.518102e+09  message          NaN          NaN          NaN    NaN
# 750332  1.518102e+09  message          NaN          NaN          NaN    NaN
# 750333  1.518102e+09  message          NaN          NaN          NaN    NaN
# 750334  1.518103e+09  message          NaN          NaN          NaN    NaN
# 750335  1.518103e+09  message          NaN          NaN          NaN    NaN
# 750336  1.518103e+09  message          NaN          NaN          NaN    NaN
# 750337  1.518103e+09  message          NaN          NaN          NaN    NaN
# 750338  1.518103e+09  message          NaN          NaN          NaN    NaN
# 750339  1.518103e+09  message          NaN          NaN          NaN    NaN
# 750340  1.518103e+09  message          NaN          NaN          2.0    NaN
# 750341  1.518103e+09  message          NaN          NaN          NaN    NaN
# 750342  1.518103e+09  message          NaN          NaN          NaN    NaN
# 750343  1.518103e+09  message          NaN          NaN          NaN    NaN
# 750344  1.518103e+09  message          NaN          NaN          NaN    NaN
# 750345  1.518103e+09  message          NaN          NaN          NaN    NaN
# 750346  1.518104e+09  message          NaN          NaN          NaN    NaN
# 750347  1.518104e+09  message          NaN          NaN          8.0    NaN
# 750348  1.518104e+09  message          NaN          NaN          NaN    NaN
# 750349  1.518104e+09  message          NaN          NaN          NaN    NaN
# 750350  1.518104e+09  message          NaN          NaN          NaN    NaN
# 750351  1.518104e+09  message          NaN          NaN          NaN    NaN
# 750352  1.518104e+09  message          NaN          NaN          NaN    NaN
# 750353  1.518104e+09  message          NaN          NaN          NaN    NaN
# 750354  1.518104e+09  message          NaN          NaN          NaN    NaN
# 750355  1.518104e+09  message          NaN          NaN          NaN    NaN
# 750356  1.518104e+09  message          NaN          NaN          NaN    NaN
#
#        upload_reply_to       user username
# 4                  NaN  U040M0W0S      NaN
# 7                  NaN  U041LH06L      NaN
# 14                 NaN  U040M0W0S      NaN
# 15                 NaN  U040M0W0S      NaN
# 16                 NaN  U040M0W0S      NaN
# 17                 NaN  U040M0W0S      NaN
# 22                 NaN  U041SH27M      NaN
# 25                 NaN  U041T0UHM      NaN
# 26                 NaN  U041T0UHM      NaN
# 33                 NaN  U040M0W0S      NaN
# 34                 NaN  U040M0W0S      NaN
# 35                 NaN  U040M0W0S      NaN
# 36                 NaN  U040M0W0S      NaN
# 40                 NaN  U041P485A      NaN
# 43                 NaN  U041LH06L      NaN
# 44                 NaN  U041P485A      NaN
# 45                 NaN  U041P485A      NaN
# 52                 NaN  U041LH06L      NaN
# 57                 NaN  U041P485A      NaN
# 58                 NaN  U041P485A      NaN
# 59                 NaN  U041LH06L      NaN
# 60                 NaN  U041P485A      NaN
# 61                 NaN  U041LH06L      NaN
# 62                 NaN  U041P485A      NaN
# 65                 NaN  U041T0UHM      NaN
# 66                 NaN  U041P485A      NaN
# 68                 NaN  U041T0UHM      NaN
# 69                 NaN  U041T0UHM      NaN
# 70                 NaN  U041T0UHM      NaN
# 71                 NaN  U041T0UHM      NaN
# ...                ...        ...      ...
# 750327             NaN  U28J6CP29      NaN
# 750328             NaN  U3VC0QX9D      NaN
# 750329             NaN  U83QJR46A      NaN
# 750330             NaN  U04ELQZAU      NaN
# 750331             NaN  U3P82LKDK      NaN
# 750332             NaN  U71N0RTPW      NaN
# 750333             NaN  U04ELQZAU      NaN
# 750334             NaN  U06J1LG1M      NaN
# 750335             NaN  U8SPJSJLE      NaN
# 750336             NaN  U14BPHDK6      NaN
# 750337             NaN  U4Z9Q18QH      NaN
# 750338             NaN  U04ELQZAU      NaN
# 750339             NaN  U719W4TSM      NaN
# 750340             NaN  U7ZRN37U2      NaN
# 750341             NaN  U719W4TSM      NaN
# 750342             NaN  U6E9SDU2K      NaN
# 750343             NaN  U04ELQZAU      NaN
# 750344             NaN  U04ELQZAU      NaN
# 750345             NaN  U6L6P415Y      NaN
# 750346             NaN  U7ZRN37U2      NaN
# 750347             NaN  U6YEN210D      NaN
# 750348             NaN  U1HHX1QS3      NaN
# 750349             NaN  U1ZAJ4FC4      NaN
# 750350             NaN  U1HHX1QS3      NaN
# 750351             NaN  U1ZAJ4FC4      NaN
# 750352             NaN  U1HHX1QS3      NaN
# 750353             NaN  U0K47J3HR      NaN
# 750354             NaN  U1HHX1QS3      NaN
# 750355             NaN  U1HHX1QS3      NaN
# 750356             NaN  U6YEN210D      NaN
#
# [614216 rows x 54 columns]

# %%
all_texts = [
    normalize_links(msg['text'])
    for msg in ods.messages
    if msg['type'] == 'message' and msg.get('subtype') is None
]

# %%
normalize_links("[{'id': 1, 'title': 'Show Me Shiny', 'fallback': 'Show Me Shiny', 'title_link': 'http://www.showmeshiny.com/', 'text': 'Gallery of R Web Apps', 'from_url': 'http://www.showmeshiny.com/'}]")
# Out:
# "[{'id': 1, 'title': 'Show Me Shiny', 'fallback': 'Show Me Shiny', 'title_link': 'http://www.showmeshiny.com/', 'text': 'Gallery of R Web Apps', 'from_url': 'http://www.showmeshiny.com/'}]"

# %%
react_texts = []
react_counts = []

for msg in ods.messages:
    if msg['type'] == 'message' and msg.get('subtype') is None:
        react_texts.append(normalize_links(msg['text']))
        
        msg_reacts = {}
        for record in msg.get('reactions', []):
            msg_reacts[record['name']] = record['count']
        react_counts.append(msg_reacts)

# %% [markdown]
# ## Reaction classifier

# %%
react_texts = []
react_counts = []

for msg in ods.messages:
    if msg['type'] == 'message' and msg.get('subtype') is None:
        react_texts.append(normalize_links(msg['text']))
        
        msg_reacts = {}
        for record in msg.get('reactions', []):
            msg_reacts[record['name']] = record['count']
        react_counts.append(msg_reacts)

# %%
import collections
unique_reacts = collections.Counter()
for c in react_counts:
    for r in c:
        unique_reacts[r] += 1

# %%
selected_reacts = [r for r, c in unique_reacts.most_common(20)]

# %%
# %%time

# we need a custom pre-processor to extract correct field,
# but want to also use default scikit-learn preprocessing (e.g. lowercasing)
default_preprocessor = CountVectorizer().build_preprocessor()
def build_preprocessor(field):
    field_idx = list(train.columns).index(field)
    return lambda x: default_preprocessor(x[field_idx])
    
vectorizer = FeatureUnion([
    ('name', CountVectorizer(
        ngram_range=(1, 2),
        max_features=50000,
        preprocessor=build_preprocessor('name'))),
    ('category_name', CountVectorizer(
        token_pattern='.+',
        preprocessor=build_preprocessor('category_name'))),
    ('brand_name', CountVectorizer(
        token_pattern='.+',
        preprocessor=build_preprocessor('brand_name'))),
    ('shipping', CountVectorizer(
        token_pattern='\d+',
        preprocessor=build_preprocessor('shipping'))),
    ('item_condition_id', CountVectorizer(
        token_pattern='\d+',
        preprocessor=build_preprocessor('item_condition_id'))),
    ('item_description', TfidfVectorizer(
        ngram_range=(1, 3),
        max_features=100000,
        preprocessor=build_preprocessor('item_description'))),
])
X_train = vectorizer.fit_transform(train.values)
X_train

# %%
X = vectorizer.transform(react_texts)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.cross_validation import StratifiedShuffleSplit, cross_val_score
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X[:1]
# Out:
# <1x44438 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>

# %%
model_react = {}
for react_target in selected_reacts:
    y = np.array([int(c.get(react_target, 0) > 0) for c in react_counts])
    model_react[react_target] = LogisticRegression().fit(X, y)

    cv = StratifiedShuffleSplit(y, random_state=123, test_size=.15, train_size=.85, n_iter=3)
    print('%s, positives %.2f%%, cv auc %.5f' % (
        react_target,
        y.mean()*100,
        cross_val_score(LogisticRegression(), X, y, cv=cv, scoring='roc_auc').mean(),
    ))
# Out:
# +1, positives 3.64%, cv auc 0.76356
# heavy_plus_sign, positives 3.36%, cv auc 0.67174
# joy, positives 0.83%, cv auc 0.74642
# notbad, positives 0.67%, cv auc 0.73281
# fire, positives 0.62%, cv auc 0.82531
# trollface, positives 0.54%, cv auc 0.72683
# 100, positives 0.53%, cv auc 0.67182
# true-story, positives 0.50%, cv auc 0.71397
# thinking_face, positives 0.38%, cv auc 0.61087
# yeah-sure, positives 0.38%, cv auc 0.69299
# povar, positives 0.37%, cv auc 0.71214
# tnx, positives 0.36%, cv auc 0.77439
# white_check_mark, positives 0.34%, cv auc 0.68639
# but_why, positives 0.31%, cv auc 0.71444
# facepalm, positives 0.29%, cv auc 0.70031
# muscle, positives 0.27%, cv auc 0.76462
# wat, positives 0.24%, cv auc 0.65878
# heavy_minus_sign, positives 0.24%, cv auc 0.68393
# +1::skin-tone-2, positives 0.23%, cv auc 0.71432
# be-a-man, positives 0.22%, cv auc 0.72027

# %%
def top_reactions(text):
    x = vectorizer.transform([text])
    preds = [
        (r, model_react[r].predict_proba(x)[0, 1])
        for r in selected_reacts
    ]
    preds.sort(key=lambda r: r[1], reverse=True)
    return preds[:5]

# %%
top_reactions(u'Можно. Тут пара человек угорала с истории про козла')
# Out:
# [('+1', 0.060079761553906388),
#  ('heavy_plus_sign', 0.043402557522066364),
#  ('fire', 0.011373006306074128),
#  ('true-story', 0.0071047773024533077),
#  ('100', 0.0066861761234894394)]

# %%
top_reactions(u'И мемесы у нас русские')
# Out:
# [('+1', 0.029399941360662086),
#  ('heavy_plus_sign', 0.021373334623936251),
#  ('true-story', 0.016139040709673886),
#  ('joy', 0.015228144460444884),
#  ('notbad', 0.0094699747929729294)]

# %%
top_reactions(u'русских у нас и так хватает')
# Out:
# [('heavy_plus_sign', 0.048699749731758536),
#  ('+1', 0.022849875710441999),
#  ('notbad', 0.013383660848396662),
#  ('trollface', 0.012859188117463956),
#  ('povar', 0.010221607962518477)]

# %%
top_reactions(u'Есть ли здесь люди, которые работают DS в аптечных сетях? Можете ли вы привести примеры конкретных задач, решенных вами и которые имели конкретный результат, выразившийся в увеличении продаж или снижении затрат?')
# Out:
# [('+1', 0.029207308970827135),
#  ('heavy_plus_sign', 0.028446037832670985),
#  ('heavy_minus_sign', 0.0069871413432184368),
#  ('thinking_face', 0.0062550711573768052),
#  ('100', 0.0043369764794703837)]

# %%
top_reactions(u'Т.е. на самом деле это не они ему придумали, а он такой "ребят своим говором вы называете меня зефиркой, давайте-ка лучше придумаем немецкое имя"')
# Out:
# [('heavy_plus_sign', 0.05380597259108541),
#  ('+1', 0.022236001392614359),
#  ('joy', 0.020444567458969495),
#  ('yeah-sure', 0.016805782291318183),
#  ('trollface', 0.015303161341876342)]

# %% [markdown]
# ## Channel classifier

# %%
channel_messages_cnt = collections.Counter(channel_labels)
selected_channels = [r for r, c in channel_messages_cnt.most_common(50)]
channel_messages_cnt.most_common(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-0466471eae01> in <module>()
# ----> 1 channel_messages_cnt = collections.Counter(channel_labels)
#       2 selected_channels = [r for r, c in channel_messages_cnt.most_common(50)]
#       3 channel_messages_cnt.most_common(50)
#
# NameError: name 'collections' is not defined

# %%
channel_texts = []
channel_labels = []

for msg in ods.messages:
    if msg['type'] == 'message' and msg.get('subtype') is None and ods.channels[msg['channel']]['name'] in selected_channels:
        channel_texts.append(normalize_links(msg['text']))
        channel_labels.append(ods.channels[msg['channel']]['name'])
        
X_channel = vectorizer.transform(channel_texts)

# %%
from sklearn.metrics import average_precision_score

# %%
for train_indices, test_indices in cv:
    model = LogisticRegression().fit(X_channel[train_indices, :], np.array(channel_labels)[train_indices])
    y_true = np.vstack([
        [int(ch == l) for ch in model.classes_]
        for l in channel_labels
    ])
    sc = average_precision_score(y_true[test_indices, :], model.predict_proba(X_channel[test_indices, :]))
    print sc
# Out:
# 0.181920245541
# 0.187385121118
# 0.189705231823

# %%
model_channel = LogisticRegression().fit(X_channel, np.array(channel_labels))

# %%
def predict_channel(text):
    X = vectorizer.transform([text])
    y_pred = model_channel.predict_proba(X)
    preds = zip(model_channel.classes_, y_pred[0, :])
    preds.sort(key=lambda (c, p): p, reverse=True)
    return preds[:5]

# %%
predict_channel(u'подскажите пожалуйста как запустить факторизационные машины')
# Out:
# [(u'theory_and_practice', 0.16790929041550848),
#  (u'python', 0.15014067919781149),
#  (u'_random_flood', 0.087561429305589536),
#  (u'_general', 0.071414662006578311),
#  (u'big_data', 0.071126243710510059)]

# %%
predict_channel(u'Слайды с семинара в ИППИ на прошлой неделе на тему "Математические модели временных рядов с трендом в задачах обнаружения разладки"')
# Out:
# [(u'_meetings', 0.44959758801100247),
#  (u'theory_and_practice', 0.19180315910086793),
#  (u'_random_flood', 0.046230132693773567),
#  (u'conference', 0.026185563394516838),
#  (u'_general', 0.024911607092178777)]

# %%
predict_channel(u'интересно, почему возраст - обязательное поле при регистрации')
# Out:
# [(u'_random_flood', 0.20119753387775735),
#  (u'_meetings', 0.084453090868886332),
#  (u'_general', 0.083119532724364092),
#  (u'python', 0.067297056103339165),
#  (u'mltrainings_beginners', 0.064526763286998134)]

# %%
predict_channel(u'''
Всем привет

В компании Criteo есть интересные позиции Data Scientist и Machine Learning Engineer разных уровней. В основном в Европе (Париж, Барселона, Амстердам, Лондон и др.), но есть также в США и Азии.

Например, есть позиция Sr. Data Analyst, где надо анализировать покупательную заинтересованность людей в оффлайн магазинах и матчить ее с данными в онлайн. Оффлайн данные поступают с маячков (iBeacons).

Есть несколько других позиций связанные с улучшением алгоритмов движка Criteo, рекомендательной системой и обработки больших данных.

Позиции full-time, on-site. Компания помогает с переездом (visa + relocation bonus).

Вот видео как круто в Criteo: https://youtu.be/i1zC3H3_gik

Если кого-то заинтересует, дайте знать, я помогу.''')
# Out:
# [(u'_jobs', 0.31460292258060213),
#  (u'career', 0.17843483191938694),
#  (u'welcome', 0.10548385943118249),
#  (u'_random_flood', 0.095441132554945046),
#  (u'_general', 0.043160697662964993)]

# %%
predict_channel(u'а можно про оффхип по подробнее?')
# Out:
# [(u'theory_and_practice', 0.18742089350918822),
#  (u'_random_flood', 0.17149058537958456),
#  (u'deep_learning', 0.10809625622781312),
#  (u'_meetings', 0.08422849061490377),
#  (u'_jobs', 0.064569827995280271)]

# %%
predict_channel(u'вы hue не используете?')
# Out:
# [(u'big_data', 0.4067488429811868),
#  (u'_random_flood', 0.13176042483251368),
#  (u'_meetings', 0.069866712736964848),
#  (u'theory_and_practice', 0.038138175807033971),
#  (u'_general', 0.036084586040766996)]

# %%
predict_channel(u'А есть докер образы со всем что нужно на кэггле? ')
# Out:
# [(u'_random_flood', 0.17477553287773115),
#  (u'theory_and_practice', 0.11370610353653217),
#  (u'_general', 0.096752516918349366),
#  (u'python', 0.075395133041503692),
#  (u'deep_learning', 0.074907382919993187)]

# %%
predict_channel(u'а кто подскажет ответ на такой примитивный вопрос (смотрю в датасет bosch) - если я обнаруживаю две фичи с четкой линейной корреляцией - какая общая рекомендация что с ними делать? Выкинуть одну? Попытаться как-то извлечь информацию из второй? Что-то еще?')
# Out:
# [(u'theory_and_practice', 0.44678177339450326),
#  (u'kaggle_crackers', 0.1769167991205596),
#  (u'deep_learning', 0.049848548157015518),
#  (u'_general', 0.033862639874370964),
#  (u'python', 0.033203761366450653)]

# %%
predict_channel(u'ты его проходишь? ну и как последняя домашка? А по Visual Recognition чего-нибудь есть? Порекомендуйте')
# Out:
# [(u'edu_courses', 0.31219710104772791),
#  (u'_random_flood', 0.071867109523670036),
#  (u'python', 0.062321987276667608),
#  (u'deep_learning', 0.058391603568720113),
#  (u'visualization', 0.051522759150720111)]
